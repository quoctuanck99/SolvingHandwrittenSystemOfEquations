# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from IPython.display import Image, clear_output  # to display images

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/yolov5/
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !unzip -q /content/drive/MyDrive/CV_Final_Project/dataset1/handwrittenEquations.v1.yolov5pytorch -d ../dataset

# %%
# Weights & Biases (optional)
# %pip install -q wandb  
# !wandb login  # use 'wandb disabled' or 'wandb enabled' to disable or enable
# Out:
#      |████████████████████████████████| 1.8MB 15.6MB/s
#      |████████████████████████████████| 81kB 11.8MB/s
#      |████████████████████████████████| 133kB 59.3MB/s
#      |████████████████████████████████| 163kB 54.5MB/s
#      |████████████████████████████████| 102kB 14.8MB/s
#      |████████████████████████████████| 71kB 12.7MB/s
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
Image(filename='/content/yolov5/runs/train/exp/test_batch0_pred.jpg', width=900)

# %%
# !python train.py --img 608 --batch 16 --epochs 100 --data /content/yolov5/data/voc.yaml --cfg yolov5l.yaml --nosave --cache --adam
# Out:
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Namespace(adam=True, batch_size=16, bucket='', cache_images=True, cfg='./models/yolov5l.yaml', data='/content/yolov5/data/voc.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[608, 608], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/exp', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-12-29 17:53:58.869994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
from utils.plots import plot_results 
plot_results(save_dir='/content/yolov5/runs/train/exp')  # plot all results*.txt as results.png
Image(filename='/content/yolov5/runs/train/exp/results.png', width=800)

# %%
# !python detect.py --source /content/drive/MyDrive/CV_Final_Project/dataset2/test/images/IMG20201229114925_jpg.rf.c5006c68da53cbf035088cf4acc18751.jpg --weights /content/yolov5/runs/train/exp/weights/last.pt --conf 0.2
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/CV_Final_Project/dataset2/test/images/IMG20201229114925_jpg.rf.c5006c68da53cbf035088cf4acc18751.jpg', update=False, view_img=False, weights=['/content/yolov5/runs/train/exp/weights/last.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Fusing layers...
# Model Summary: 400 layers, 47364662 parameters, 0 gradients, 115.8 GFLOPS
# image 1/1 /content/drive/MyDrive/CV_Final_Project/dataset2/test/images/IMG20201229114925_jpg.rf.c5006c68da53cbf035088cf4acc18751.jpg: 640x640 3 equations, Done. (0.035s)
# Results saved to runs/detect/exp2
# Done. (0.074s)

# %%
Image(filename='/content/yolov5/runs/detect/exp2/IMG20201229114925_jpg.rf.c5006c68da53cbf035088cf4acc18751.jpg')
